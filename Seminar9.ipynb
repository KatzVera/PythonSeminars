# %% [markdown]
# <a href="https://colab.research.google.com/github/KatzVera/PythonSeminars/blob/main/Seminar9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv') # скачать файл

# %%
df.tail(10) #вывод строк с конца. head - вывод строк с начана
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16990      1530.0       653.0         1.7038             78300.0
# ...

# %%
df.shape # размер таблицы
# Out:
# (17000, 9)

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
df.isnull().sum() # подсчет нулевых значений по столбцам
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
tb = df['total_bedrooms'] # присвоение переменной столбцу

# %%
tb.sum()
# Out:
# 9169984.0

# %%
df[['latitude', 'longitude']] # срез по 2м столбцам
# Out:
#        latitude  longitude
# 0         34.19    -114.31
# 1         34.40    -114.47
# 2         33.69    -114.56
# 3         33.64    -114.57
# 4         33.57    -114.57
# ...         ...        ...
# 16995     40.58    -124.26
# 16996     40.69    -124.27
# 16997     41.84    -124.30
# 16998     41.80    -124.30
# 16999     40.54    -124.35
#
# [17000 rows x 2 columns]

# %%
new = df[(df['housing_median_age'] < 20) & (df['total_rooms'] < 30)] # фильтр по столбцам и условиям

# %%
new
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2907    -117.76     35.22                 4.0         18.0             3.0
# 2990    -117.79     35.21                 4.0          2.0             2.0
# 3275    -117.86     33.67                16.0         20.0             5.0
# 8232    -118.44     34.04                16.0         18.0             6.0
#
#       population  households  median_income  median_house_value
# 2907         8.0         6.0          1.625            275000.0
# 2990         6.0         2.0          2.375            137500.0
# 3275        15.0         5.0          3.875            450000.0
# 8232         3.0         4.0          0.536            350000.0

# %%
new.shape
# Out:
# (4, 9)

# %%
new['population'].min() # в новой таблице минимум по столбцу
# Out:
# 3.0

# %%
new['population'].mean() # mean - поиск среднего значения
# Out:
# 8.0

# %%
new['population'].sum()
# Out:
# 32.0

# %%
df[(df['median_income'] < 2)]['median_house_value']
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0

# %%
df[(df['median_income'] == 3.1250)]['median_house_value'].max()
# Out:
# 380400.0

# %%
minimum = df['median_house_value'].min() # нашли минимум по столбцу и запомнили в переменную

# %%
df[(df['median_house_value'] == minimum)]['population'].max() # нашли все значения с этим минимумом и по нему сдулали отбор по стобцу
# Out:
# 628.0
